# %%
ASSIGNMENT ON SMOKING

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Dell E7470\Desktop\Data Analysis\smoking.csv")
df
# Out:
#       gender  age marital_status highest_qualification nationality ethnicity  \
# 0       Male   38       Divorced      No Qualification     British     White
# 1     Female   42         Single      No Qualification     British     White
# 2       Male   40        Married                Degree     English     White
# 3     Female   40        Married                Degree     English     White
# 4     Female   39        Married          GCSE/O Level     British     White
# ...      ...  ...            ...                   ...         ...       ...
# 1686    Male   22         Single      No Qualification    Scottish     White
# 1687  Female   49       Divorced      Other/Sub Degree     English     White
# 1688    Male   45        Married      Other/Sub Degree    Scottish     White
# 1689  Female   51        Married      No Qualification     English     White
# 1690    Male   31        Married                Degree    Scottish     White
#
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#       gender  age marital_status highest_qualification nationality ethnicity  \
# 0       Male   38       Divorced      No Qualification     British     White
# 1     Female   42         Single      No Qualification     British     White
# 2       Male   40        Married                Degree     English     White
# 3     Female   40        Married                Degree     English     White
# 4     Female   39        Married          GCSE/O Level     British     White
# ...      ...  ...            ...                   ...         ...       ...
# 1686    Male   22         Single      No Qualification    Scottish     White
# 1687  Female   49       Divorced      Other/Sub Degree     English     White
# 1688    Male   45        Married      Other/Sub Degree    Scottish     White
# 1689  Female   51        Married      No Qualification     English     White
# 1690    Male   31        Married                Degree    Scottish     White
#
# ...

# %%
df = df.drop(columns= 'ethnicity')
df
# Out:
#       gender  age marital_status highest_qualification nationality  \
# 0       Male   38       Divorced      No Qualification     British
# 1     Female   42         Single      No Qualification     British
# 2       Male   40        Married                Degree     English
# 3     Female   40        Married                Degree     English
# 4     Female   39        Married          GCSE/O Level     British
# ...      ...  ...            ...                   ...         ...
# 1686    Male   22         Single      No Qualification    Scottish
# 1687  Female   49       Divorced      Other/Sub Degree     English
# 1688    Male   45        Married      Other/Sub Degree    Scottish
# 1689  Female   51        Married      No Qualification     English
# 1690    Male   31        Married                Degree    Scottish
#
#           gross_income     region smoke  amt_weekends  amt_weekdays  \
# 0       2,600 to 5,200  The North    No           NaN           NaN
# ...

# %%
df = df.drop(columns= 'amt_weekends')
df
# Out:
#       gender  age marital_status highest_qualification nationality  \
# 0       Male   38       Divorced      No Qualification     British
# 1     Female   42         Single      No Qualification     British
# 2       Male   40        Married                Degree     English
# 3     Female   40        Married                Degree     English
# 4     Female   39        Married          GCSE/O Level     British
# ...      ...  ...            ...                   ...         ...
# 1686    Male   22         Single      No Qualification    Scottish
# 1687  Female   49       Divorced      Other/Sub Degree     English
# 1688    Male   45        Married      Other/Sub Degree    Scottish
# 1689  Female   51        Married      No Qualification     English
# 1690    Male   31        Married                Degree    Scottish
#
#           gross_income     region smoke  amt_weekdays         type
# 0       2,600 to 5,200  The North    No           NaN          NaN
# ...
