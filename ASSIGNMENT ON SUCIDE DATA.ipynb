# %% [markdown]
# ASSIGNMENT

# %%
import pandas as pd
pd.set_option('display.max.row', 118556 )
df = pd.read_csv(r"C:\Users\Dell E7470\Desktop\Data Analysis\suicide_rates_1990-2022.csv")
df
# Out:
#        RegionCode                       RegionName CountryCode  \
# 0              EU                           Europe         ALB
# 1              EU                           Europe         ALB
# 2              EU                           Europe         ALB
# 3              EU                           Europe         ALB
# 4              EU                           Europe         ALB
# ...           ...                              ...         ...
# 118555        NAC  North America and the Caribbean         USA
# 118556        NAC  North America and the Caribbean         USA
# 118557        NAC  North America and the Caribbean         USA
# 118558        NAC  North America and the Caribbean         USA
# 118559        NAC  North America and the Caribbean         USA
#
#                      CountryName  Year     Sex     AgeGroup  \
# 0                        Albania  1992    Male   0-14 years
# 1                        Albania  1992    Male   0-14 years
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#        RegionCode                       RegionName CountryCode  \
# 0              EU                           Europe         ALB
# 4              EU                           Europe         ALB
# 5              EU                           Europe         ALB
# 6              EU                           Europe         ALB
# 7              EU                           Europe         ALB
# ...           ...                              ...         ...
# 118555        NAC  North America and the Caribbean         USA
# 118556        NAC  North America and the Caribbean         USA
# 118557        NAC  North America and the Caribbean         USA
# 118558        NAC  North America and the Caribbean         USA
# 118559        NAC  North America and the Caribbean         USA
#
#                      CountryName  Year     Sex     AgeGroup  \
# 0                        Albania  1992    Male   0-14 years
# 4                        Albania  1992    Male  15-24 years
# ...

# %%
df = df.drop(columns= 'RegionCode')
df
# Out:
#                              RegionName CountryCode               CountryName  \
# 0                                Europe         ALB                   Albania
# 4                                Europe         ALB                   Albania
# 5                                Europe         ALB                   Albania
# 6                                Europe         ALB                   Albania
# 7                                Europe         ALB                   Albania
# ...                                 ...         ...                       ...
# 118555  North America and the Caribbean         USA  United States of America
# 118556  North America and the Caribbean         USA  United States of America
# 118557  North America and the Caribbean         USA  United States of America
# 118558  North America and the Caribbean         USA  United States of America
# 118559  North America and the Caribbean         USA  United States of America
#
# ...

# %%
df = df.drop(columns= 'CountryCode')
df
# Out:
#                              RegionName               CountryName  Year  \
# 0                                Europe                   Albania  1992
# 4                                Europe                   Albania  1992
# 5                                Europe                   Albania  1992
# 6                                Europe                   Albania  1992
# 7                                Europe                   Albania  1992
# ...                                 ...                       ...   ...
# 118555  North America and the Caribbean  United States of America  2021
# 118556  North America and the Caribbean  United States of America  2021
# 118557  North America and the Caribbean  United States of America  2021
# 118558  North America and the Caribbean  United States of America  2021
# 118559  North America and the Caribbean  United States of America  2021
#
#            Sex     AgeGroup         Generation  SuicideCount  \
# ...

# %%
df = df.drop_Unknown()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17688\865595000.py in ?()
# ----> 1 df = df.drop_Unknown()
#
# c:\Users\Dell E7470\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_Unknown'
